# %%
from PenneySimulation import *

# %%
generate_sequence(420, [1,2,3,4,5])
# Out:
# [4, 5, 3, 1, 2]

# %%
my_deck = '111000111'
seq1 = '111'
seq2 = '100'
score_deck(my_deck, seq1, seq2) # p1cards, p2cards, p1tricks, p2tricks
# Out:
# (9, 0, 2, 0)

# %%
generate_data(200_000)
# Out:
# Generated 200000/200000 card decks.
# Saving decks...
# Done.

# %%
generate_data(800_000)
# Out:
# Generated 800000/800000 card decks.
# Saving decks...
# Done.

# %%
get_heatmaps('png')
# Out:
# Ran 1000000 simulations.
# Saved results.json in data folder.

# %%
get_heatmaps('html')
# Out:
# figs/cards.html saved successfully.
# figs/tricks.html saved successfully.
